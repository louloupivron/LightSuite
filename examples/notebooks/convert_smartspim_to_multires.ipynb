# %% [markdown]
# # Convert SmartSPIM / ASI exports to LightSuite Multires Pair v1
#
# Use this notebook to parse vendor-specific `metadata.txt` files and plane-per-file
# `All_Channels/` stacks, then publish a `multires_pair_manifest.json` for
# `lightsuite multires`.
#
# **TODO:** implement ASI metadata parsing and mosaic origin solver here.
# The pipeline core (`lightsuite multires`) only reads the manifest — no vendor parsing.

# %%
from pathlib import Path

DATA_ROOT = Path("/media/gbm/NVME2/ALICe-pipelines-data/Multi_RES_SCANs")
OVERVIEW_STACK = DATA_ROOT / "1_6X/All_Channels"
ROI_STACK = DATA_ROOT / "9X/20260710_11_03_38_9X_single__FOV"  # flatten/stitch first
OVERVIEW_META = DATA_ROOT / "1_6X/metadata.txt"
ROI_META = DATA_ROOT / "9X/20260710_11_03_38_9X_single__FOV/metadata.txt"

SAVE_PATH = DATA_ROOT / "registration_results"
CONVERTED_DIR = SAVE_PATH / "converted"
CONVERTED_DIR.mkdir(parents=True, exist_ok=True)
MANIFEST_PATH = CONVERTED_DIR / "single_fov_pair.json"

# %%
# from lightsuite.multires.models import MANIFEST_FORMAT, MultiresPairManifest, ManifestVolumeSpec
# from lightsuite.multires.manifest import save_pair_manifest
#
# 1. Parse ASI metadata.txt (um/pix, Z step, tile table, z/focus)
# 2. Infer origin_um / spacing_um / direction for overview and ROI
# 3. Optionally write flattened TIFF stacks; manifest may point at folders
# 4. save_pair_manifest(manifest, MANIFEST_PATH)
raise NotImplementedError("SmartSPIM conversion — implement metadata parsing in this notebook")
